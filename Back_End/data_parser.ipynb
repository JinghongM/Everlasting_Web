# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import codecs
import csv

# %%
file = pd.read_csv('data_v1.csv')

# %%
file
# Out:
#             Unnamed: 0 Sizes for all Boy size Girl size          All  \
# 0                Brand           NaN      NaN       NaN       Height
# 1                 #sen         6-9mo      NaN       NaN          NaN
# 2                 #sen        9-12mo      NaN       NaN          NaN
# 3                 #sen       12-18mo      NaN       NaN          NaN
# 4                 #sen       18-24mo      NaN       NaN          NaN
# 5                 #sen            2Y      NaN       NaN          NaN
# 6                 #sen            3Y      NaN       NaN          NaN
# 7                 #sen            4Y      NaN       NaN          NaN
# 8                 #sen            5Y      NaN       NaN          NaN
# 9                 #sen            6Y      NaN       NaN          NaN
# 10                #sen            6X      NaN       NaN          NaN
# 11                #sen            7Y      NaN       NaN          NaN
# 12                #sen            8Y      NaN       NaN          NaN
# ...

# %%
names = names

# %%
names = [
    'brand', 'size_for_all', 'boy_size','girl_size','all_height',
    'all_weight', 'boy_height','boy_weight','girl_height', 'girl_weight'
]

# %%
convertor_data = file[['Unnamed: 0','Sizes for all','Boy size','Girl size','All',
 'Unnamed: 5','Boy','Unnamed: 7','Girl','Unnamed: 9']]
convertor_data.head(6)
# Out:
#   Unnamed: 0 Sizes for all Boy size Girl size     All Unnamed: 5     Boy  \
# 0      Brand           NaN      NaN       NaN  Height     Weight  Height
# 1       #sen         6-9mo      NaN       NaN     NaN        NaN     NaN
# 2       #sen        9-12mo      NaN       NaN     NaN        NaN     NaN
# 3       #sen       12-18mo      NaN       NaN     NaN        NaN     NaN
# 4       #sen       18-24mo      NaN       NaN     NaN        NaN     NaN
# 5       #sen            2Y      NaN       NaN     NaN        NaN     NaN
#
#   Unnamed: 7    Girl Unnamed: 9
# 0     Weight  Height     Weight
# 1        NaN     NaN        NaN
# 2        NaN     NaN        NaN
# 3        NaN     NaN        NaN
# 4        NaN     NaN        NaN
# 5        NaN     NaN        NaN

# %%
# file.rename_axis({"Unnamed: 0":"brand"},axis = "columns")
convertor_data = convertor_data.rename_axis({
    'Unnamed: 0':'brand','Sizes for all':'size_for_all',
    'Boy size':'boy_size','Girl size':'girl_size','All':'all_height',
 'Unnamed: 5':'all_weight','Boy':'boy_height',
    'Unnamed: 7':'boy_weight','Girl':'girl_height',
    'Unnamed: 9':'girl_weight'
}, axis = 'columns')

# %%
convertor_data
# Out:
#                  brand  size_for_all boy_size girl_size   all_height  \
# 0                Brand           NaN      NaN       NaN       Height
# 1                 #sen         6-9mo      NaN       NaN          NaN
# 2                 #sen        9-12mo      NaN       NaN          NaN
# 3                 #sen       12-18mo      NaN       NaN          NaN
# 4                 #sen       18-24mo      NaN       NaN          NaN
# 5                 #sen            2Y      NaN       NaN          NaN
# 6                 #sen            3Y      NaN       NaN          NaN
# 7                 #sen            4Y      NaN       NaN          NaN
# 8                 #sen            5Y      NaN       NaN          NaN
# 9                 #sen            6Y      NaN       NaN          NaN
# 10                #sen            6X      NaN       NaN          NaN
# 11                #sen            7Y      NaN       NaN          NaN
# 12                #sen            8Y      NaN       NaN          NaN
# ...

# %%
names_all = ['all_size','boy_size','girl_size','all_height','all_weight','boy_height',
         'boy_weight','girl_height','girl_weight','boy_top_long_chest',
         'boy_top_long_sleeve','boy_top_long_height','boy_top_long_sweep',
         'boy_top_long_undefined','boy_top_short_chest','boy_top_short_sleeve',
         'boy_top_short_height','boy_top_short_sweep','boy_bottom_pants_height',
         'boy_bottom_pants_crotch','boy_bottom_pants_waist','boy_bottom_pants_hip',
         'boy_bottom_pants_inseam','boy_bottom_pants_adjustable','boy_bottom_short_waist',
         'boy_bottom_short_hip','boy_bottom_short_inseam','boy_bottom_short_adjustable',
         'girl_top_long_chest','girl_top_long_sleeve','girl_top_long_height','girl_top_long_sweep',
         'girl_top_short_chest','girl_top_short_sleeve','girl_top_short_height',
         'girl_top_short_sweep','girl_bottom_long_waist','girl_bottom_long_hip','girl_bottom_long_inseam',
         'girl_bottom_long_adjustable','girl_bottom_short_waist','girl_bottom_short_hip',
         'girl_bottom_short_inseam','girl_bottom_short_adjustable','girl_dress_hollow_to_floor',
         'girl_dress_bust', 'girl_dress_waist','girl_dress_hips','girl_dress_sleeve',
         'girl_dress_inseam','girl_dress_height']

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import codecs
import csv

# %%
file = pd.read_csv('data_v8.csv', names = names_all)

# %%
file.head()
# Out:
#             all_size  boy_size  girl_size all_height all_weight boy_height  \
# NaN    Sizes for all  Boy size  Girl size        All        NaN        Boy
# Brand            NaN       NaN        NaN     Height     Weight     Height
# #sen           6-9mo       NaN        NaN        NaN        NaN        NaN
# #sen          9-12mo       NaN        NaN        NaN        NaN        NaN
# #sen         12-18mo       NaN        NaN        NaN        NaN        NaN
#
#       boy_weight girl_height girl_weight     boy_top_long_chest  \
# NaN          NaN        Girl         NaN  boy Top (long sleeve)
# Brand     Weight      Height      Weight                  Chest
# #sen         NaN         NaN         NaN                    NaN
# #sen         NaN         NaN         NaN                    NaN
# #sen         NaN         NaN         NaN                    NaN
#
#              ...        girl_bottom_short_hip girl_bottom_short_inseam  \
# NaN          ...                          NaN                      NaN
# Brand        ...                          Hip                   Inseam
# #sen         ...                          NaN                      NaN
# #sen         ...                          NaN                      NaN
# #sen         ...                          NaN                      NaN
#
#       girl_bottom_short_adjustable  girl_dress_hollow_to_floor  \
# NaN                            NaN                  Girl Dress
# Brand               Adjustable Y/N             Hollow to Floor
# #sen                           NaN                         NaN
# #sen                           NaN                         NaN
# #sen                           NaN                         NaN
#
#       girl_dress_bust girl_dress_waist girl_dress_hips girl_dress_sleeve  \
# NaN               NaN              NaN             NaN               NaN
# Brand            Bust            Waist            Hips            sleeve
# #sen              NaN              NaN             NaN               NaN
# #sen              NaN              NaN             NaN               NaN
# #sen              NaN              NaN             NaN               NaN
#
#       girl_dress_inseam girl_dress_height
# NaN                 NaN               NaN
# Brand            Inseam            height
# #sen                NaN               NaN
# #sen                NaN               NaN
# #sen                NaN               NaN
#
# [5 rows x 51 columns]

# %%
file = file.iloc[2:]
file["boy_actual_height"] = np.nan
file["girl_actual_height"] = np.nan

# %%
import re
unit = None
def checkUnit(data):
    unit = None
    if data[-1] is "\"":
        unit = 'inches'
    elif data[-2:] is 'cm' or 'CM':
        unit = 'cm'
    return unit

def heightParser(data, unit):
    if data is None:
        return
    nums = data.split('-')
    if unit is 'cm':
        return float(re.findall(r'\d+\.?\d+', nums[len(nums) - 1])[0])
    else:
        return float(re.findall(r'\d+\.?\d+', nums[len(nums) - 1])[0]) * 2.54

# %%
def height_generalizer(data, unit):
    if data is None:
        return
    nums = re.findall(r'\d+\.?\d+', data)
    if len(nums) is 1:
        return nums[0] + unit
    else:
        return nums[0] + '-' + nums[1] + unit

# %%
# names_all = ['all_size','boy_size','girl_size','all_height','all_weight','boy_height',
#        'boy_weight','girl_height''girl_weight','boy_top_long_chest',
#         'boy_top_long_sleeve','boy_top_long_height','boy_top_long_sweep',
#         'boy_top_long_undefined','boy_top_short_chest','boy_top_short_sleeve',
#         'boy_top_short_height','boy_top_short_sweep','boy_bottom_pants_height',
#        'boy_bottom_pants_crotch','boy_bottom_pants_waist','boy_bottom_pants_hip',
#         'boy_bottom_pants_inseam','boy_bottom_pants_adjustable','boy_bottom_short_waist',
#         'boy_bottom_short_hip','boy_bottom_short_inseam','boy_bottom_short_adjustable',
#         'girl_top_long_chest','girl_top_long_sleeve','girl_top_long_height','girl_top_long_sweep',
#         'girl_top_short_chest','girl_top_short_sleeve','girl_top_short_height',
#         'girl_top_short_sweep','girl_bottom_long_waist','girl_bottom_long_hip','girl_bottom_long_inseam',
#         'girl_bottom_long_adjustable','girl_bottom_short_waist','girl_bottom_short_hip',
#         'girl_bottom_short_inseam','girl_bottom_short_adjustable','girl_dress_hollow_to_floor',
#         'girl_dress_bust', 'girl_dress_waist','girl_dress_hips','girl_dress_sleeve',
#         'girl_dress_inseam','girl_dress_height']
all_height = file['all_height'].values
boy_height = file['boy_height'].values
girl_height = file['girl_height'].values
boy_actual_height = file['boy_actual_height'].values
girl_actual_height = file['girl_actual_height'].values
boy_top_long_height = file['boy_top_long_height'].values
boy_top_short_height = file['boy_top_short_height'].values
boy_bottom_pants_height = file['boy_bottom_pants_height'].values
girl_top_long_height = file['girl_top_long_height'].values
girl_top_short_height = file['girl_top_short_height'].values
girl_dress_height = file['girl_dress_height'].values

# %%
import math  # math.isnan(x) check if x is nan
unit = None
for i in range(len(all_height)):
    if type(all_height[i]) is str or math.isnan(all_height[i]) is False:
        data = str(all_height[i])
        if checkUnit(data) is not None:
            unit = checkUnit(data)
        ah = None
        try:
            ah = heightParser(data, unit)
        except ValueError as ve:
            print('could not convert string to float')
        except IndexError as ie:
            print('index out of range')
        general_height = height_generalizer(data, unit)
        if general_height is not None:
            all_height[i] = general_height
        boy_actual_height[i] = ah
        girl_actual_height[i] = ah
for i in range(len(boy_height)):
    if type(boy_height[i]) is str or math.isnan(boy_height[i]) is False:
        data = str(boy_height[i])
        if checkUnit(data) is not None:
            unit = checkUnit(data)
        bh = None
        try:
            bh = heightParser(data, unit)
        except ValueError as ve:
            print('could not convert string to float')
        except IndexError as ie:
            print('index out of range')
        general_height = height_generalizer(data, unit)
        if general_height is not None:
            boy_height[i] = general_height
        boy_actual_height[i] = bh
for i in range(len(girl_height)):
    if type(girl_height[i]) is str or math.isnan(girl_height[i]) is False:
        data = str(girl_height[i])
        if checkUnit(data) is not None:
            unit = checkUnit(data)
        gh = None
        try:
            gh = heightParser(data, unit)
        except ValueError as ve:
            print('could not convert string to float')
        except IndexError as ie:
            print('index out of range')
        general_height = height_generalizer(data, unit)
        if general_height is not None:
            girl_height[i] = general_height
        girl_actual_height[i] = gh
for i in range(len(boy_top_long_height)):
    if math.isnan(boy_actual_height[i]) is False:
        continue
    if type(boy_top_long_height[i]) is str or math.isnan(boy_top_long_height[i]) is False:
        data = str(boy_top_long_height[i])
        if checkUnit(data) is not None:
            unit = checkUnit(data)
        gh = None
        try:
            gh = heightParser(data, unit)
        except ValueError as ve:
            print('could not convert string to float')
        except IndexError as ie:
            print('index out of range')
        general_height = height_generalizer(data, unit)
        if general_height is not None:
            boy_top_long_height[i] = general_height
        boy_actual_height[i] = gh
        
for i in range(len(boy_top_short_height)):
    if math.isnan(boy_actual_height[i]) is False:
        continue
    if type(boy_top_short_height[i]) is str or math.isnan(boy_top_short_height[i]) is False:
        data = str(boy_top_short_height[i])
        if checkUnit(data) is not None:
            unit = checkUnit(data)
        gh = None
        try:
            gh = heightParser(data, unit)
        except ValueError as ve:
            print('could not convert string to float')
        except IndexError as ie:
            print('index out of range')
        general_height = height_generalizer(data, unit)
        if general_height is not None:
            boy_top_short_height[i] = general_height
        boy_actual_height[i] = gh
        
for i in range(len(girl_top_long_height)):
    if math.isnan(girl_actual_height[i]) is False:
        continue
    if type(girl_top_long_height[i]) is str or math.isnan(girl_top_long_height[i]) is False:
        data = str(girl_top_long_height[i])
        if checkUnit(data) is not None:
            unit = checkUnit(data)
        gh = None
        try:
            gh = heightParser(data, unit)
        except ValueError as ve:
            print('could not convert string to float')
        except IndexError as ie:
            print('index out of range')
        general_height = height_generalizer(data, unit)
        if general_height is not None:
            girl_top_long_height[i] = general_height
        girl_actual_height[i] = gh
        
for i in range(len(girl_dress_height)):
    if math.isnan(girl_actual_height[i]) is False:
        continue
    if type(girl_dress_height[i]) is str or math.isnan(girl_dress_height[i]) is False:
        data = str(girl_dress_height[i])
        if checkUnit(data) is not None:
            unit = checkUnit(data)
        gh = None
        try:
            gh = heightParser(data, unit)
        except ValueError as ve:
            print('could not convert string to float')
        except IndexError as ie:
            print('index out of range')
        general_height = height_generalizer(data, unit)
        if general_height is not None:
            girl_dress_height[i] = general_height
        girl_actual_height[i] = gh

# %%
file['boy_actual_height'] = boy_actual_height
file['girl_actual_height'] = girl_actual_height
file
# Out:
#                   all_size boy_size girl_size all_height all_weight  \
# #sen                 6-9mo      NaN       NaN        NaN        NaN
# #sen                9-12mo      NaN       NaN        NaN        NaN
# #sen               12-18mo      NaN       NaN        NaN        NaN
# #sen               18-24mo      NaN       NaN        NaN        NaN
# #sen                    2Y      NaN       NaN        NaN        NaN
# #sen                    3Y      NaN       NaN        NaN        NaN
# #sen                    4Y      NaN       NaN        NaN        NaN
# #sen                    5Y      NaN       NaN        NaN        NaN
# #sen                    6Y      NaN       NaN        NaN        NaN
# #sen                    6X      NaN       NaN        NaN        NaN
# #sen                    7Y      NaN       NaN        NaN        NaN
# #sen                    8Y      NaN       NaN        NaN        NaN
# #sen                   10Y      NaN       NaN        NaN        NaN
# #sen                   12Y      NaN       NaN        NaN        NaN
# #sen                   14Y      NaN       NaN        NaN        NaN
# NaN                    NaN      NaN       NaN        NaN        NaN
# NaN                    NaN      NaN       NaN        NaN        NaN
# 7 for All Mankind   9-12mo      NaN       NaN     30.5cm        NaN
# 7 for All Mankind  12-18mo      NaN       NaN       32cm        NaN
# 7 for All Mankind  18-24mo      NaN       NaN       35cm        NaN
# 7 for All Mankind       2Y      NaN       NaN       35cm        NaN
# 7 for All Mankind       3Y      NaN       NaN       38cm        NaN
# 7 for All Mankind       4Y      NaN       NaN       41cm        NaN
# 7 for All Mankind       5Y      NaN       NaN     43.5cm        NaN
# 7 for All Mankind       6Y      NaN       NaN       46cm        NaN
# 7 for All Mankind       6X      NaN       NaN     48.5cm        NaN
# 7 for All Mankind       7Y      NaN       NaN       51cm        NaN
# 7 for All Mankind       8Y      NaN       NaN       53cm        NaN
# 7 for All Mankind      10Y      NaN       NaN       55cm        NaN
# 7 for All Mankind      12Y      NaN       NaN       58cm        NaN
# ...                    ...      ...       ...        ...        ...
# NaN                    NaN      NaN       NaN        NaN        NaN
# NaN                    NaN      NaN       NaN        NaN        NaN
# NaN                    NaN      NaN       NaN        NaN        NaN
# NaN                    NaN      NaN       NaN        NaN        NaN
# NaN                    NaN      NaN       NaN        NaN        NaN
# NaN                    NaN      NaN       NaN        NaN        NaN
# Billy Bandit            6m      NaN       NaN       67cm        NaN
# Billy Bandit            9m      NaN       NaN       71cm        NaN
# Billy Bandit            12      NaN       NaN       74cm        NaN
# Billy Bandit            18      NaN       NaN       81cm        NaN
# Billy Bandit            2y      NaN       NaN       86cm        NaN
# Billy Bandit             3      NaN       NaN       94cm        NaN
# Billy Bandit             4      NaN       NaN      102cm        NaN
# Billy Bandit             5      NaN       NaN      108cm        NaN
# Billy Bandit             6      NaN       NaN      114cm        NaN
# Billy Bandit             8      NaN       NaN      126cm        NaN
# Billy Bandit            10      NaN       NaN      138cm        NaN
# Billy Bandit            12      NaN       NaN      150cm        NaN
# NaN                    NaN      NaN       NaN        NaN        NaN
# popupshop            6-12m      NaN       NaN       80cm        NaN
# popupshop           12-18m      NaN       NaN       86cm        NaN
# popupshop             1-2y      NaN       NaN       92cm        NaN
# popupshop             2-3y      NaN       NaN       98cm        NaN
# popupshop             3-4y      NaN       NaN      104cm        NaN
# popupshop             4-5y      NaN       NaN      110cm        NaN
# popupshop             5-6y      NaN       NaN      116cm        NaN
# popupshop             6-7y      NaN       NaN      122cm        NaN
# popupshop             7-8y      NaN       NaN      128cm        NaN
# popupshop            9-10y      NaN       NaN      140cm        NaN
# popupshop           11-12y      NaN       NaN      152cm        NaN
#
#                   boy_height boy_weight girl_height girl_weight  \
# #sen                     NaN        NaN         NaN         NaN
# #sen                     NaN        NaN         NaN         NaN
# #sen                     NaN        NaN         NaN         NaN
# #sen                     NaN        NaN         NaN         NaN
# #sen                     NaN        NaN         NaN         NaN
# #sen                     NaN        NaN         NaN         NaN
# #sen                     NaN        NaN         NaN         NaN
# #sen                     NaN        NaN         NaN         NaN
# #sen                     NaN        NaN         NaN         NaN
# #sen                     NaN        NaN         NaN         NaN
# #sen                     NaN        NaN         NaN         NaN
# #sen                     NaN        NaN         NaN         NaN
# #sen                     NaN        NaN         NaN         NaN
# #sen                     NaN        NaN         NaN         NaN
# #sen                     NaN        NaN         NaN         NaN
# NaN                      NaN        NaN         NaN         NaN
# NaN                      NaN        NaN         NaN         NaN
# 7 for All Mankind        NaN        NaN         NaN         NaN
# 7 for All Mankind        NaN        NaN         NaN         NaN
# 7 for All Mankind        NaN        NaN         NaN         NaN
# 7 for All Mankind        NaN        NaN         NaN         NaN
# 7 for All Mankind        NaN        NaN         NaN         NaN
# 7 for All Mankind        NaN        NaN         NaN         NaN
# 7 for All Mankind        NaN        NaN         NaN         NaN
# 7 for All Mankind        NaN        NaN         NaN         NaN
# 7 for All Mankind        NaN        NaN         NaN         NaN
# 7 for All Mankind        NaN        NaN         NaN         NaN
# 7 for All Mankind        NaN        NaN         NaN         NaN
# 7 for All Mankind        NaN        NaN         NaN         NaN
# 7 for All Mankind        NaN        NaN         NaN         NaN
# ...                      ...        ...         ...         ...
# NaN                      NaN        NaN         NaN         NaN
# NaN                      NaN        NaN         NaN         NaN
# NaN                      NaN        NaN         NaN         NaN
# NaN                      NaN        NaN         NaN         NaN
# NaN                      NaN        NaN         NaN         NaN
# NaN                      NaN        NaN         NaN         NaN
# Billy Bandit             NaN        NaN         NaN         NaN
# Billy Bandit             NaN        NaN         NaN         NaN
# Billy Bandit             NaN        NaN         NaN         NaN
# Billy Bandit             NaN        NaN         NaN         NaN
# Billy Bandit             NaN        NaN         NaN         NaN
# Billy Bandit             NaN        NaN         NaN         NaN
# Billy Bandit             NaN        NaN         NaN         NaN
# Billy Bandit             NaN        NaN         NaN         NaN
# Billy Bandit             NaN        NaN         NaN         NaN
# Billy Bandit             NaN        NaN         NaN         NaN
# Billy Bandit             NaN        NaN         NaN         NaN
# Billy Bandit             NaN        NaN         NaN         NaN
# NaN                      NaN        NaN         NaN         NaN
# popupshop                NaN        NaN         NaN         NaN
# popupshop                NaN        NaN         NaN         NaN
# popupshop                NaN        NaN         NaN         NaN
# popupshop                NaN        NaN         NaN         NaN
# popupshop                NaN        NaN         NaN         NaN
# popupshop                NaN        NaN         NaN         NaN
# popupshop                NaN        NaN         NaN         NaN
# popupshop                NaN        NaN         NaN         NaN
# popupshop                NaN        NaN         NaN         NaN
# popupshop                NaN        NaN         NaN         NaN
# popupshop                NaN        NaN         NaN         NaN
#
#                   boy_top_long_chest        ...          \
# #sen                             NaN        ...
# #sen                             NaN        ...
# #sen                             NaN        ...
# #sen                             NaN        ...
# #sen                             NaN        ...
# #sen                             NaN        ...
# #sen                             NaN        ...
# #sen                             NaN        ...
# #sen                             NaN        ...
# #sen                             NaN        ...
# #sen                             NaN        ...
# #sen                             NaN        ...
# #sen                             NaN        ...
# #sen                             NaN        ...
# #sen                             NaN        ...
# NaN                              NaN        ...
# NaN                              NaN        ...
# 7 for All Mankind                19"        ...
# 7 for All Mankind            19 3/4"        ...
# 7 for All Mankind            20 1/2"        ...
# 7 for All Mankind            20 1/2"        ...
# 7 for All Mankind                21"        ...
# 7 for All Mankind                22"        ...
# 7 for All Mankind                23"        ...
# 7 for All Mankind                24"        ...
# 7 for All Mankind                25"        ...
# 7 for All Mankind                26"        ...
# 7 for All Mankind                27"        ...
# 7 for All Mankind              28.5"        ...
# 7 for All Mankind                30"        ...
# ...                              ...        ...
# NaN                              NaN        ...
# NaN                              NaN        ...
# NaN                              NaN        ...
# NaN                              NaN        ...
# NaN                              NaN        ...
# NaN                              NaN        ...
# Billy Bandit                     NaN        ...
# Billy Bandit                     NaN        ...
# Billy Bandit                     NaN        ...
# Billy Bandit                     NaN        ...
# Billy Bandit                     NaN        ...
# Billy Bandit                     NaN        ...
# Billy Bandit                     NaN        ...
# Billy Bandit                     NaN        ...
# Billy Bandit                     NaN        ...
# Billy Bandit                     NaN        ...
# Billy Bandit                     NaN        ...
# Billy Bandit                     NaN        ...
# NaN                              NaN        ...
# popupshop                         52        ...
# popupshop                         54        ...
# popupshop                         56        ...
# popupshop                         57        ...
# popupshop                         58        ...
# popupshop                         59        ...
# popupshop                         60        ...
# popupshop                         62        ...
# popupshop                         64        ...
# popupshop                         68        ...
# popupshop                         76        ...
#
#                   girl_bottom_short_adjustable girl_dress_hollow_to_floor  \
# #sen                                       NaN                        NaN
# #sen                                       NaN                        NaN
# #sen                                       NaN                        NaN
# #sen                                       NaN                        NaN
# #sen                                       NaN                        NaN
# #sen                                       NaN                        NaN
# #sen                                       NaN                        NaN
# #sen                                       NaN                        NaN
# #sen                                       NaN                        NaN
# #sen                                       NaN                        NaN
# #sen                                       NaN                        NaN
# #sen                                       NaN                        NaN
# #sen                                       NaN                        NaN
# #sen                                       NaN                        NaN
# #sen                                       NaN                        NaN
# NaN                                        NaN                        NaN
# NaN                                        NaN                        NaN
# 7 for All Mankind                          NaN                        NaN
# 7 for All Mankind                          NaN                        NaN
# 7 for All Mankind                          NaN                        NaN
# 7 for All Mankind                          NaN                        NaN
# 7 for All Mankind                          NaN                        NaN
# 7 for All Mankind                          NaN                        NaN
# 7 for All Mankind                          NaN                        NaN
# 7 for All Mankind                          NaN                        NaN
# 7 for All Mankind                          NaN                        NaN
# 7 for All Mankind                          NaN                        NaN
# 7 for All Mankind                          NaN                        NaN
# 7 for All Mankind                          NaN                        NaN
# 7 for All Mankind                          NaN                        NaN
# ...                                        ...                        ...
# NaN                                        NaN                        NaN
# NaN                                        NaN                        NaN
# NaN                                        NaN                        NaN
# NaN                                        NaN                        NaN
# NaN                                        NaN                        NaN
# NaN                                        NaN                        NaN
# Billy Bandit                               NaN                        NaN
# Billy Bandit                               NaN                        NaN
# Billy Bandit                               NaN                        NaN
# Billy Bandit                               NaN                        NaN
# Billy Bandit                               NaN                        NaN
# Billy Bandit                               NaN                        NaN
# Billy Bandit                               NaN                        NaN
# Billy Bandit                               NaN                        NaN
# Billy Bandit                               NaN                        NaN
# Billy Bandit                               NaN                        NaN
# Billy Bandit                               NaN                        NaN
# Billy Bandit                               NaN                        NaN
# NaN                                        NaN                        NaN
# popupshop                                  NaN                        NaN
# popupshop                                  NaN                        NaN
# popupshop                                  NaN                        NaN
# popupshop                                  NaN                        NaN
# popupshop                                  NaN                        NaN
# popupshop                                  NaN                        NaN
# popupshop                                  NaN                        NaN
# popupshop                                  NaN                        NaN
# popupshop                                  NaN                        NaN
# popupshop                                  NaN                        NaN
# popupshop                                  NaN                        NaN
#
#                   girl_dress_bust  girl_dress_waist girl_dress_hips  \
# #sen                          NaN               NaN             NaN
# #sen                          NaN               NaN             NaN
# #sen                          NaN               NaN             NaN
# #sen                          NaN               NaN             NaN
# #sen                          NaN               NaN             NaN
# #sen                          NaN               NaN             NaN
# #sen                          NaN               NaN             NaN
# #sen                          NaN               NaN             NaN
# #sen                          NaN               NaN             NaN
# #sen                          NaN               NaN             NaN
# #sen                          NaN               NaN             NaN
# #sen                          NaN               NaN             NaN
# #sen                          NaN               NaN             NaN
# #sen                          NaN               NaN             NaN
# #sen                          NaN               NaN             NaN
# NaN                           NaN               NaN             NaN
# NaN                           NaN               NaN             NaN
# 7 for All Mankind             NaN               NaN             NaN
# 7 for All Mankind             NaN               NaN             NaN
# 7 for All Mankind             NaN               NaN             NaN
# 7 for All Mankind             NaN               NaN             NaN
# 7 for All Mankind             NaN               NaN             NaN
# 7 for All Mankind             NaN               NaN             NaN
# 7 for All Mankind             NaN               NaN             NaN
# 7 for All Mankind             NaN               NaN             NaN
# 7 for All Mankind             NaN               NaN             NaN
# 7 for All Mankind             NaN               NaN             NaN
# 7 for All Mankind             NaN               NaN             NaN
# 7 for All Mankind             NaN               NaN             NaN
# 7 for All Mankind             NaN               NaN             NaN
# ...                           ...               ...             ...
# NaN                           NaN               NaN             NaN
# NaN                           NaN               NaN             NaN
# NaN                           NaN               NaN             NaN
# NaN                           NaN               NaN             NaN
# NaN                           NaN               NaN             NaN
# NaN                           NaN               NaN             NaN
# Billy Bandit                  NaN               NaN             NaN
# Billy Bandit                  NaN               NaN             NaN
# Billy Bandit                  NaN               NaN             NaN
# Billy Bandit                  NaN               NaN             NaN
# Billy Bandit                  NaN               NaN             NaN
# Billy Bandit                  NaN               NaN             NaN
# Billy Bandit                  NaN               NaN             NaN
# Billy Bandit                  NaN               NaN             NaN
# Billy Bandit                  NaN               NaN             NaN
# Billy Bandit                  NaN               NaN             NaN
# Billy Bandit                  NaN               NaN             NaN
# Billy Bandit                  NaN               NaN             NaN
# NaN                           NaN               NaN             NaN
# popupshop                     NaN               NaN             NaN
# popupshop                     NaN               NaN             NaN
# popupshop                     NaN               NaN             NaN
# popupshop                     NaN               NaN             NaN
# popupshop                     NaN               NaN             NaN
# popupshop                     NaN               NaN             NaN
# popupshop                     NaN               NaN             NaN
# popupshop                     NaN               NaN             NaN
# popupshop                     NaN               NaN             NaN
# popupshop                     NaN               NaN             NaN
# popupshop                     NaN               NaN             NaN
#
#                   girl_dress_sleeve girl_dress_inseam girl_dress_height  \
# #sen                            NaN               NaN               NaN
# #sen                            NaN               NaN               NaN
# #sen                            NaN               NaN               NaN
# #sen                            NaN               NaN               NaN
# #sen                            NaN               NaN               NaN
# #sen                            NaN               NaN               NaN
# #sen                            NaN               NaN               NaN
# #sen                            NaN               NaN               NaN
# #sen                            NaN               NaN               NaN
# #sen                            NaN               NaN               NaN
# #sen                            NaN               NaN               NaN
# #sen                            NaN               NaN               NaN
# #sen                            NaN               NaN               NaN
# #sen                            NaN               NaN               NaN
# #sen                            NaN               NaN               NaN
# NaN                             NaN               NaN               NaN
# NaN                             NaN               NaN               NaN
# 7 for All Mankind               NaN               NaN               NaN
# 7 for All Mankind               NaN               NaN               NaN
# 7 for All Mankind               NaN               NaN               NaN
# 7 for All Mankind               NaN               NaN               NaN
# 7 for All Mankind               NaN               NaN               NaN
# 7 for All Mankind               NaN               NaN               NaN
# 7 for All Mankind               NaN               NaN               NaN
# 7 for All Mankind               NaN               NaN               NaN
# 7 for All Mankind               NaN               NaN               NaN
# 7 for All Mankind               NaN               NaN               NaN
# 7 for All Mankind               NaN               NaN               NaN
# 7 for All Mankind               NaN               NaN               NaN
# 7 for All Mankind               NaN               NaN               NaN
# ...                             ...               ...               ...
# NaN                             NaN               NaN               NaN
# NaN                             NaN               NaN               NaN
# NaN                             NaN               NaN               NaN
# NaN                             NaN               NaN               NaN
# NaN                             NaN               NaN               NaN
# NaN                             NaN               NaN               NaN
# Billy Bandit                    NaN               NaN               NaN
# Billy Bandit                    NaN               NaN               NaN
# Billy Bandit                    NaN               NaN               NaN
# Billy Bandit                    NaN               NaN               NaN
# Billy Bandit                    NaN               NaN               NaN
# Billy Bandit                    NaN               NaN               NaN
# Billy Bandit                    NaN               NaN               NaN
# Billy Bandit                    NaN               NaN               NaN
# Billy Bandit                    NaN               NaN               NaN
# Billy Bandit                    NaN               NaN               NaN
# Billy Bandit                    NaN               NaN               NaN
# Billy Bandit                    NaN               NaN               NaN
# NaN                             NaN               NaN               NaN
# popupshop                       NaN               NaN               NaN
# popupshop                       NaN               NaN               NaN
# popupshop                       NaN               NaN               NaN
# popupshop                       NaN               NaN               NaN
# popupshop                       NaN               NaN               NaN
# popupshop                       NaN               NaN               NaN
# popupshop                       NaN               NaN               NaN
# popupshop                       NaN               NaN               NaN
# popupshop                       NaN               NaN               NaN
# popupshop                       NaN               NaN               NaN
# popupshop                       NaN               NaN               NaN
#
#                   boy_actual_height girl_actual_height
# #sen                            NaN                NaN
# #sen                            NaN                NaN
# #sen                            NaN                NaN
# #sen                            NaN                NaN
# #sen                            NaN                NaN
# #sen                            NaN                NaN
# #sen                            NaN                NaN
# #sen                            NaN                NaN
# #sen                            NaN                NaN
# #sen                            NaN                NaN
# #sen                            NaN                NaN
# #sen                            NaN                NaN
# #sen                            NaN                NaN
# #sen                            NaN                NaN
# #sen                            NaN                NaN
# NaN                             NaN                NaN
# NaN                             NaN                NaN
# 7 for All Mankind              30.5               30.5
# 7 for All Mankind              32.0               32.0
# 7 for All Mankind              35.0               35.0
# 7 for All Mankind              35.0               35.0
# 7 for All Mankind              38.0               38.0
# 7 for All Mankind              41.0               41.0
# 7 for All Mankind              43.5               43.5
# 7 for All Mankind              46.0               46.0
# 7 for All Mankind              48.5               48.5
# 7 for All Mankind              51.0               51.0
# 7 for All Mankind              53.0               53.0
# 7 for All Mankind              55.0               55.0
# 7 for All Mankind              58.0               58.0
# ...                             ...                ...
# NaN                             NaN                NaN
# NaN                             NaN                NaN
# NaN                             NaN                NaN
# NaN                             NaN                NaN
# NaN                             NaN                NaN
# NaN                             NaN                NaN
# Billy Bandit                   67.0               67.0
# Billy Bandit                   71.0               71.0
# Billy Bandit                   74.0               74.0
# Billy Bandit                   81.0               81.0
# Billy Bandit                   86.0               86.0
# Billy Bandit                   94.0               94.0
# Billy Bandit                  102.0              102.0
# Billy Bandit                  108.0              108.0
# Billy Bandit                  114.0              114.0
# Billy Bandit                  126.0              126.0
# Billy Bandit                  138.0              138.0
# Billy Bandit                  150.0              150.0
# NaN                             NaN                NaN
# popupshop                      80.0               80.0
# popupshop                      86.0               86.0
# popupshop                      92.0               92.0
# popupshop                      98.0               98.0
# popupshop                     104.0              104.0
# popupshop                     110.0              110.0
# popupshop                     116.0              116.0
# popupshop                     122.0              122.0
# popupshop                     128.0              128.0
# popupshop                     140.0              140.0
# popupshop                     152.0              152.0
#
# [1021 rows x 53 columns]

# %%
file = file.dropna(axis = 0, how = 'all')

# %%
file = file.reset_index()

# %%
print(type(file['boy_size'][2]))
# fs stand for fillingSize
all_size = file['all_size']
boy_size = file['boy_size']
girl_size = file['girl_size']
for i in range(len(all_size)):
    if type(boy_size[i]) is not str and math.isnan(boy_size[i]) is True:
        boy_size[i] = all_size[i]
    if type(girl_size[i]) is not str and math.isnan(girl_size[i]) is True:
        girl_size[i] = all_size[i]
file['boy_size'] = boy_size
file['girl_size'] = girl_size
file
# Out:
# <class 'float'>
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
#                  index      all_size      boy_size     girl_size all_height  \
# 0                 #sen         6-9mo         6-9mo         6-9mo        NaN
# 1                 #sen        9-12mo        9-12mo        9-12mo        NaN
# 2                 #sen       12-18mo       12-18mo       12-18mo        NaN
# 3                 #sen       18-24mo       18-24mo       18-24mo        NaN
# 4                 #sen            2Y            2Y            2Y        NaN
# 5                 #sen            3Y            3Y            3Y        NaN
# 6                 #sen            4Y            4Y            4Y        NaN
# 7                 #sen            5Y            5Y            5Y        NaN
# 8                 #sen            6Y            6Y            6Y        NaN
# 9                 #sen            6X            6X            6X        NaN
# 10                #sen            7Y            7Y            7Y        NaN
# 11                #sen            8Y            8Y            8Y        NaN
# 12                #sen           10Y           10Y           10Y        NaN
# 13                #sen           12Y           12Y           12Y        NaN
# 14                #sen           14Y           14Y           14Y        NaN
# 15   7 for All Mankind        9-12mo        9-12mo        9-12mo     30.5cm
# 16   7 for All Mankind       12-18mo       12-18mo       12-18mo       32cm
# 17   7 for All Mankind       18-24mo       18-24mo       18-24mo       35cm
# 18   7 for All Mankind            2Y            2Y            2Y       35cm
# 19   7 for All Mankind            3Y            3Y            3Y       38cm
# 20   7 for All Mankind            4Y            4Y            4Y       41cm
# 21   7 for All Mankind            5Y            5Y            5Y     43.5cm
# 22   7 for All Mankind            6Y            6Y            6Y       46cm
# 23   7 for All Mankind            6X            6X            6X     48.5cm
# 24   7 for All Mankind            7Y            7Y            7Y       51cm
# 25   7 for All Mankind            8Y            8Y            8Y       53cm
# 26   7 for All Mankind           10Y           10Y           10Y       55cm
# 27   7 for All Mankind           12Y           12Y           12Y       58cm
# 28   7 for All Mankind           14Y           14Y           14Y       61cm
# 29                A076            2Y            2Y            2Y       92cm
# ..                 ...           ...           ...           ...        ...
# 857       Zaza Couture            10            10            10    54-55cm
# 858       Zaza Couture            12            12            12    56-57cm
# 859       Zaza Couture            14            14            14    58-59cm
# 860       Zaza Couture            16            16            16    60-61cm
# 861             Zutano   6-12 months   6-12 months   6-12 months    26-28cm
# 862             Zutano  12-18 months  12-18 months  12-18 months    28-30cm
# 863             Zutano  18-24 months  18-24 months  18-24 months    30-32cm
# 864       Billy Bandit            6m            6m            6m       67cm
# 865       Billy Bandit            9m            9m            9m       71cm
# 866       Billy Bandit            12            12            12       74cm
# 867       Billy Bandit            18            18            18       81cm
# 868       Billy Bandit            2y            2y            2y       86cm
# 869       Billy Bandit             3             3             3       94cm
# 870       Billy Bandit             4             4             4      102cm
# 871       Billy Bandit             5             5             5      108cm
# 872       Billy Bandit             6             6             6      114cm
# 873       Billy Bandit             8             8             8      126cm
# 874       Billy Bandit            10            10            10      138cm
# 875       Billy Bandit            12            12            12      150cm
# 876          popupshop         6-12m         6-12m         6-12m       80cm
# 877          popupshop        12-18m        12-18m        12-18m       86cm
# 878          popupshop          1-2y          1-2y          1-2y       92cm
# 879          popupshop          2-3y          2-3y          2-3y       98cm
# 880          popupshop          3-4y          3-4y          3-4y      104cm
# 881          popupshop          4-5y          4-5y          4-5y      110cm
# 882          popupshop          5-6y          5-6y          5-6y      116cm
# 883          popupshop          6-7y          6-7y          6-7y      122cm
# 884          popupshop          7-8y          7-8y          7-8y      128cm
# 885          popupshop         9-10y         9-10y         9-10y      140cm
# 886          popupshop        11-12y        11-12y        11-12y      152cm
#
#       all_weight boy_height boy_weight girl_height girl_weight  \
# 0            NaN        NaN        NaN         NaN         NaN
# 1            NaN        NaN        NaN         NaN         NaN
# 2            NaN        NaN        NaN         NaN         NaN
# 3            NaN        NaN        NaN         NaN         NaN
# 4            NaN        NaN        NaN         NaN         NaN
# 5            NaN        NaN        NaN         NaN         NaN
# 6            NaN        NaN        NaN         NaN         NaN
# 7            NaN        NaN        NaN         NaN         NaN
# 8            NaN        NaN        NaN         NaN         NaN
# 9            NaN        NaN        NaN         NaN         NaN
# 10           NaN        NaN        NaN         NaN         NaN
# 11           NaN        NaN        NaN         NaN         NaN
# 12           NaN        NaN        NaN         NaN         NaN
# 13           NaN        NaN        NaN         NaN         NaN
# 14           NaN        NaN        NaN         NaN         NaN
# 15           NaN        NaN        NaN         NaN         NaN
# 16           NaN        NaN        NaN         NaN         NaN
# 17           NaN        NaN        NaN         NaN         NaN
# 18           NaN        NaN        NaN         NaN         NaN
# 19           NaN        NaN        NaN         NaN         NaN
# 20           NaN        NaN        NaN         NaN         NaN
# 21           NaN        NaN        NaN         NaN         NaN
# 22           NaN        NaN        NaN         NaN         NaN
# 23           NaN        NaN        NaN         NaN         NaN
# 24           NaN        NaN        NaN         NaN         NaN
# 25           NaN        NaN        NaN         NaN         NaN
# 26           NaN        NaN        NaN         NaN         NaN
# 27           NaN        NaN        NaN         NaN         NaN
# 28           NaN        NaN        NaN         NaN         NaN
# 29           NaN        NaN        NaN         NaN         NaN
# ..           ...        ...        ...         ...         ...
# 857   64-72 lbs.        NaN        NaN         NaN         NaN
# 858   72-80 lbs.        NaN        NaN         NaN         NaN
# 859   80-90 lbs.        NaN        NaN         NaN         NaN
# 860  90-100 lbs.        NaN        NaN         NaN         NaN
# 861   17-22 lbs.        NaN        NaN         NaN         NaN
# 862   22-27 lbs.        NaN        NaN         NaN         NaN
# 863   27-30 lbs.        NaN        NaN         NaN         NaN
# 864          NaN        NaN        NaN         NaN         NaN
# 865          NaN        NaN        NaN         NaN         NaN
# 866          NaN        NaN        NaN         NaN         NaN
# 867          NaN        NaN        NaN         NaN         NaN
# 868          NaN        NaN        NaN         NaN         NaN
# 869          NaN        NaN        NaN         NaN         NaN
# 870          NaN        NaN        NaN         NaN         NaN
# 871          NaN        NaN        NaN         NaN         NaN
# 872          NaN        NaN        NaN         NaN         NaN
# 873          NaN        NaN        NaN         NaN         NaN
# 874          NaN        NaN        NaN         NaN         NaN
# 875          NaN        NaN        NaN         NaN         NaN
# 876          NaN        NaN        NaN         NaN         NaN
# 877          NaN        NaN        NaN         NaN         NaN
# 878          NaN        NaN        NaN         NaN         NaN
# 879          NaN        NaN        NaN         NaN         NaN
# 880          NaN        NaN        NaN         NaN         NaN
# 881          NaN        NaN        NaN         NaN         NaN
# 882          NaN        NaN        NaN         NaN         NaN
# 883          NaN        NaN        NaN         NaN         NaN
# 884          NaN        NaN        NaN         NaN         NaN
# 885          NaN        NaN        NaN         NaN         NaN
# 886          NaN        NaN        NaN         NaN         NaN
#
#            ...         girl_bottom_short_adjustable  \
# 0          ...                                  NaN
# 1          ...                                  NaN
# 2          ...                                  NaN
# 3          ...                                  NaN
# 4          ...                                  NaN
# 5          ...                                  NaN
# 6          ...                                  NaN
# 7          ...                                  NaN
# 8          ...                                  NaN
# 9          ...                                  NaN
# 10         ...                                  NaN
# 11         ...                                  NaN
# 12         ...                                  NaN
# 13         ...                                  NaN
# 14         ...                                  NaN
# 15         ...                                  NaN
# 16         ...                                  NaN
# 17         ...                                  NaN
# 18         ...                                  NaN
# 19         ...                                  NaN
# 20         ...                                  NaN
# 21         ...                                  NaN
# 22         ...                                  NaN
# 23         ...                                  NaN
# 24         ...                                  NaN
# 25         ...                                  NaN
# 26         ...                                  NaN
# 27         ...                                  NaN
# 28         ...                                  NaN
# 29         ...                                  NaN
# ..         ...                                  ...
# 857        ...                                  NaN
# 858        ...                                  NaN
# 859        ...                                  NaN
# 860        ...                                  NaN
# 861        ...                                  NaN
# 862        ...                                  NaN
# 863        ...                                  NaN
# 864        ...                                  NaN
# 865        ...                                  NaN
# 866        ...                                  NaN
# 867        ...                                  NaN
# 868        ...                                  NaN
# 869        ...                                  NaN
# 870        ...                                  NaN
# 871        ...                                  NaN
# 872        ...                                  NaN
# 873        ...                                  NaN
# 874        ...                                  NaN
# 875        ...                                  NaN
# 876        ...                                  NaN
# 877        ...                                  NaN
# 878        ...                                  NaN
# 879        ...                                  NaN
# 880        ...                                  NaN
# 881        ...                                  NaN
# 882        ...                                  NaN
# 883        ...                                  NaN
# 884        ...                                  NaN
# 885        ...                                  NaN
# 886        ...                                  NaN
#
#     girl_dress_hollow_to_floor girl_dress_bust girl_dress_waist  \
# 0                          NaN             NaN              NaN
# 1                          NaN             NaN              NaN
# 2                          NaN             NaN              NaN
# 3                          NaN             NaN              NaN
# 4                          NaN             NaN              NaN
# 5                          NaN             NaN              NaN
# 6                          NaN             NaN              NaN
# 7                          NaN             NaN              NaN
# 8                          NaN             NaN              NaN
# 9                          NaN             NaN              NaN
# 10                         NaN             NaN              NaN
# 11                         NaN             NaN              NaN
# 12                         NaN             NaN              NaN
# 13                         NaN             NaN              NaN
# 14                         NaN             NaN              NaN
# 15                         NaN             NaN              NaN
# 16                         NaN             NaN              NaN
# 17                         NaN             NaN              NaN
# 18                         NaN             NaN              NaN
# 19                         NaN             NaN              NaN
# 20                         NaN             NaN              NaN
# 21                         NaN             NaN              NaN
# 22                         NaN             NaN              NaN
# 23                         NaN             NaN              NaN
# 24                         NaN             NaN              NaN
# 25                         NaN             NaN              NaN
# 26                         NaN             NaN              NaN
# 27                         NaN             NaN              NaN
# 28                         NaN             NaN              NaN
# 29                         NaN             NaN              NaN
# ..                         ...             ...              ...
# 857                        NaN             NaN              NaN
# 858                        NaN             NaN              NaN
# 859                        NaN             NaN              NaN
# 860                        NaN             NaN              NaN
# 861                        NaN             NaN              NaN
# 862                        NaN             NaN              NaN
# 863                        NaN             NaN              NaN
# 864                        NaN             NaN              NaN
# 865                        NaN             NaN              NaN
# 866                        NaN             NaN              NaN
# 867                        NaN             NaN              NaN
# 868                        NaN             NaN              NaN
# 869                        NaN             NaN              NaN
# 870                        NaN             NaN              NaN
# 871                        NaN             NaN              NaN
# 872                        NaN             NaN              NaN
# 873                        NaN             NaN              NaN
# 874                        NaN             NaN              NaN
# 875                        NaN             NaN              NaN
# 876                        NaN             NaN              NaN
# 877                        NaN             NaN              NaN
# 878                        NaN             NaN              NaN
# 879                        NaN             NaN              NaN
# 880                        NaN             NaN              NaN
# 881                        NaN             NaN              NaN
# 882                        NaN             NaN              NaN
# 883                        NaN             NaN              NaN
# 884                        NaN             NaN              NaN
# 885                        NaN             NaN              NaN
# 886                        NaN             NaN              NaN
#
#      girl_dress_hips girl_dress_sleeve girl_dress_inseam girl_dress_height  \
# 0                NaN               NaN               NaN               NaN
# 1                NaN               NaN               NaN               NaN
# 2                NaN               NaN               NaN               NaN
# 3                NaN               NaN               NaN               NaN
# 4                NaN               NaN               NaN               NaN
# 5                NaN               NaN               NaN               NaN
# 6                NaN               NaN               NaN               NaN
# 7                NaN               NaN               NaN               NaN
# 8                NaN               NaN               NaN               NaN
# 9                NaN               NaN               NaN               NaN
# 10               NaN               NaN               NaN               NaN
# 11               NaN               NaN               NaN               NaN
# 12               NaN               NaN               NaN               NaN
# 13               NaN               NaN               NaN               NaN
# 14               NaN               NaN               NaN               NaN
# 15               NaN               NaN               NaN               NaN
# 16               NaN               NaN               NaN               NaN
# 17               NaN               NaN               NaN               NaN
# 18               NaN               NaN               NaN               NaN
# 19               NaN               NaN               NaN               NaN
# 20               NaN               NaN               NaN               NaN
# 21               NaN               NaN               NaN               NaN
# 22               NaN               NaN               NaN               NaN
# 23               NaN               NaN               NaN               NaN
# 24               NaN               NaN               NaN               NaN
# 25               NaN               NaN               NaN               NaN
# 26               NaN               NaN               NaN               NaN
# 27               NaN               NaN               NaN               NaN
# 28               NaN               NaN               NaN               NaN
# 29               NaN               NaN               NaN               NaN
# ..               ...               ...               ...               ...
# 857              NaN               NaN               NaN               NaN
# 858              NaN               NaN               NaN               NaN
# 859              NaN               NaN               NaN               NaN
# 860              NaN               NaN               NaN               NaN
# 861              NaN               NaN               NaN               NaN
# 862              NaN               NaN               NaN               NaN
# 863              NaN               NaN               NaN               NaN
# 864              NaN               NaN               NaN               NaN
# 865              NaN               NaN               NaN               NaN
# 866              NaN               NaN               NaN               NaN
# 867              NaN               NaN               NaN               NaN
# 868              NaN               NaN               NaN               NaN
# 869              NaN               NaN               NaN               NaN
# 870              NaN               NaN               NaN               NaN
# 871              NaN               NaN               NaN               NaN
# 872              NaN               NaN               NaN               NaN
# 873              NaN               NaN               NaN               NaN
# 874              NaN               NaN               NaN               NaN
# 875              NaN               NaN               NaN               NaN
# 876              NaN               NaN               NaN               NaN
# 877              NaN               NaN               NaN               NaN
# 878              NaN               NaN               NaN               NaN
# 879              NaN               NaN               NaN               NaN
# 880              NaN               NaN               NaN               NaN
# 881              NaN               NaN               NaN               NaN
# 882              NaN               NaN               NaN               NaN
# 883              NaN               NaN               NaN               NaN
# 884              NaN               NaN               NaN               NaN
# 885              NaN               NaN               NaN               NaN
# 886              NaN               NaN               NaN               NaN
#
#     boy_actual_height girl_actual_height
# 0                 NaN                NaN
# 1                 NaN                NaN
# 2                 NaN                NaN
# 3                 NaN                NaN
# 4                 NaN                NaN
# 5                 NaN                NaN
# 6                 NaN                NaN
# 7                 NaN                NaN
# 8                 NaN                NaN
# 9                 NaN                NaN
# 10                NaN                NaN
# 11                NaN                NaN
# 12                NaN                NaN
# 13                NaN                NaN
# 14                NaN                NaN
# 15               30.5               30.5
# 16               32.0               32.0
# 17               35.0               35.0
# 18               35.0               35.0
# 19               38.0               38.0
# 20               41.0               41.0
# 21               43.5               43.5
# 22               46.0               46.0
# 23               48.5               48.5
# 24               51.0               51.0
# 25               53.0               53.0
# 26               55.0               55.0
# 27               58.0               58.0
# 28               61.0               61.0
# 29               92.0               92.0
# ..                ...                ...
# 857              55.0               55.0
# 858              57.0               57.0
# 859              59.0               59.0
# 860              61.0               61.0
# 861              28.0               28.0
# 862              30.0               30.0
# 863              32.0               32.0
# 864              67.0               67.0
# 865              71.0               71.0
# 866              74.0               74.0
# 867              81.0               81.0
# 868              86.0               86.0
# 869              94.0               94.0
# 870             102.0              102.0
# 871             108.0              108.0
# 872             114.0              114.0
# 873             126.0              126.0
# 874             138.0              138.0
# 875             150.0              150.0
# 876              80.0               80.0
# 877              86.0               86.0
# 878              92.0               92.0
# 879              98.0               98.0
# 880             104.0              104.0
# 881             110.0              110.0
# 882             116.0              116.0
# 883             122.0              122.0
# 884             128.0              128.0
# 885             140.0              140.0
# 886             152.0              152.0
#
# [887 rows x 54 columns]

# %%
all_height = file['all_height']
boy_height = file['boy_height']
girl_height = file['girl_height']
for i in range(len(all_height)):
    if type(boy_height[i]) is not str and math.isnan(boy_height[i]) is True:
        boy_height[i] = all_height[i]
    if type(girl_height[i]) is not str and math.isnan(girl_height[i]) is True:
        girl_height[i] = all_height[i]
file['boy_height'] = boy_height
file['girl_height'] = girl_height
file
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                  index      all_size      boy_size     girl_size all_height  \
# 0                 #sen         6-9mo         6-9mo         6-9mo        NaN
# 1                 #sen        9-12mo        9-12mo        9-12mo        NaN
# 2                 #sen       12-18mo       12-18mo       12-18mo        NaN
# 3                 #sen       18-24mo       18-24mo       18-24mo        NaN
# 4                 #sen            2Y            2Y            2Y        NaN
# 5                 #sen            3Y            3Y            3Y        NaN
# 6                 #sen            4Y            4Y            4Y        NaN
# 7                 #sen            5Y            5Y            5Y        NaN
# 8                 #sen            6Y            6Y            6Y        NaN
# 9                 #sen            6X            6X            6X        NaN
# 10                #sen            7Y            7Y            7Y        NaN
# 11                #sen            8Y            8Y            8Y        NaN
# 12                #sen           10Y           10Y           10Y        NaN
# 13                #sen           12Y           12Y           12Y        NaN
# 14                #sen           14Y           14Y           14Y        NaN
# 15   7 for All Mankind        9-12mo        9-12mo        9-12mo     30.5cm
# 16   7 for All Mankind       12-18mo       12-18mo       12-18mo       32cm
# 17   7 for All Mankind       18-24mo       18-24mo       18-24mo       35cm
# 18   7 for All Mankind            2Y            2Y            2Y       35cm
# 19   7 for All Mankind            3Y            3Y            3Y       38cm
# 20   7 for All Mankind            4Y            4Y            4Y       41cm
# 21   7 for All Mankind            5Y            5Y            5Y     43.5cm
# 22   7 for All Mankind            6Y            6Y            6Y       46cm
# 23   7 for All Mankind            6X            6X            6X     48.5cm
# 24   7 for All Mankind            7Y            7Y            7Y       51cm
# 25   7 for All Mankind            8Y            8Y            8Y       53cm
# 26   7 for All Mankind           10Y           10Y           10Y       55cm
# 27   7 for All Mankind           12Y           12Y           12Y       58cm
# 28   7 for All Mankind           14Y           14Y           14Y       61cm
# 29                A076            2Y            2Y            2Y       92cm
# ..                 ...           ...           ...           ...        ...
# 857       Zaza Couture            10            10            10    54-55cm
# 858       Zaza Couture            12            12            12    56-57cm
# 859       Zaza Couture            14            14            14    58-59cm
# 860       Zaza Couture            16            16            16    60-61cm
# 861             Zutano   6-12 months   6-12 months   6-12 months    26-28cm
# 862             Zutano  12-18 months  12-18 months  12-18 months    28-30cm
# 863             Zutano  18-24 months  18-24 months  18-24 months    30-32cm
# 864       Billy Bandit            6m            6m            6m       67cm
# 865       Billy Bandit            9m            9m            9m       71cm
# 866       Billy Bandit            12            12            12       74cm
# 867       Billy Bandit            18            18            18       81cm
# 868       Billy Bandit            2y            2y            2y       86cm
# 869       Billy Bandit             3             3             3       94cm
# 870       Billy Bandit             4             4             4      102cm
# 871       Billy Bandit             5             5             5      108cm
# 872       Billy Bandit             6             6             6      114cm
# 873       Billy Bandit             8             8             8      126cm
# 874       Billy Bandit            10            10            10      138cm
# 875       Billy Bandit            12            12            12      150cm
# 876          popupshop         6-12m         6-12m         6-12m       80cm
# 877          popupshop        12-18m        12-18m        12-18m       86cm
# 878          popupshop          1-2y          1-2y          1-2y       92cm
# 879          popupshop          2-3y          2-3y          2-3y       98cm
# 880          popupshop          3-4y          3-4y          3-4y      104cm
# 881          popupshop          4-5y          4-5y          4-5y      110cm
# 882          popupshop          5-6y          5-6y          5-6y      116cm
# 883          popupshop          6-7y          6-7y          6-7y      122cm
# 884          popupshop          7-8y          7-8y          7-8y      128cm
# 885          popupshop         9-10y         9-10y         9-10y      140cm
# 886          popupshop        11-12y        11-12y        11-12y      152cm
#
#       all_weight boy_height boy_weight girl_height girl_weight  \
# 0            NaN        NaN        NaN         NaN         NaN
# 1            NaN        NaN        NaN         NaN         NaN
# 2            NaN        NaN        NaN         NaN         NaN
# 3            NaN        NaN        NaN         NaN         NaN
# 4            NaN        NaN        NaN         NaN         NaN
# 5            NaN        NaN        NaN         NaN         NaN
# 6            NaN        NaN        NaN         NaN         NaN
# 7            NaN        NaN        NaN         NaN         NaN
# 8            NaN        NaN        NaN         NaN         NaN
# 9            NaN        NaN        NaN         NaN         NaN
# 10           NaN        NaN        NaN         NaN         NaN
# 11           NaN        NaN        NaN         NaN         NaN
# 12           NaN        NaN        NaN         NaN         NaN
# 13           NaN        NaN        NaN         NaN         NaN
# 14           NaN        NaN        NaN         NaN         NaN
# 15           NaN     30.5cm        NaN      30.5cm         NaN
# 16           NaN       32cm        NaN        32cm         NaN
# 17           NaN       35cm        NaN        35cm         NaN
# 18           NaN       35cm        NaN        35cm         NaN
# 19           NaN       38cm        NaN        38cm         NaN
# 20           NaN       41cm        NaN        41cm         NaN
# 21           NaN     43.5cm        NaN      43.5cm         NaN
# 22           NaN       46cm        NaN        46cm         NaN
# 23           NaN     48.5cm        NaN      48.5cm         NaN
# 24           NaN       51cm        NaN        51cm         NaN
# 25           NaN       53cm        NaN        53cm         NaN
# 26           NaN       55cm        NaN        55cm         NaN
# 27           NaN       58cm        NaN        58cm         NaN
# 28           NaN       61cm        NaN        61cm         NaN
# 29           NaN       92cm        NaN        92cm         NaN
# ..           ...        ...        ...         ...         ...
# 857   64-72 lbs.    54-55cm        NaN     54-55cm         NaN
# 858   72-80 lbs.    56-57cm        NaN     56-57cm         NaN
# 859   80-90 lbs.    58-59cm        NaN     58-59cm         NaN
# 860  90-100 lbs.    60-61cm        NaN     60-61cm         NaN
# 861   17-22 lbs.    26-28cm        NaN     26-28cm         NaN
# 862   22-27 lbs.    28-30cm        NaN     28-30cm         NaN
# 863   27-30 lbs.    30-32cm        NaN     30-32cm         NaN
# 864          NaN       67cm        NaN        67cm         NaN
# 865          NaN       71cm        NaN        71cm         NaN
# 866          NaN       74cm        NaN        74cm         NaN
# 867          NaN       81cm        NaN        81cm         NaN
# 868          NaN       86cm        NaN        86cm         NaN
# 869          NaN       94cm        NaN        94cm         NaN
# 870          NaN      102cm        NaN       102cm         NaN
# 871          NaN      108cm        NaN       108cm         NaN
# 872          NaN      114cm        NaN       114cm         NaN
# 873          NaN      126cm        NaN       126cm         NaN
# 874          NaN      138cm        NaN       138cm         NaN
# 875          NaN      150cm        NaN       150cm         NaN
# 876          NaN       80cm        NaN        80cm         NaN
# 877          NaN       86cm        NaN        86cm         NaN
# 878          NaN       92cm        NaN        92cm         NaN
# 879          NaN       98cm        NaN        98cm         NaN
# 880          NaN      104cm        NaN       104cm         NaN
# 881          NaN      110cm        NaN       110cm         NaN
# 882          NaN      116cm        NaN       116cm         NaN
# 883          NaN      122cm        NaN       122cm         NaN
# 884          NaN      128cm        NaN       128cm         NaN
# 885          NaN      140cm        NaN       140cm         NaN
# 886          NaN      152cm        NaN       152cm         NaN
#
#            ...         girl_bottom_short_adjustable  \
# 0          ...                                  NaN
# 1          ...                                  NaN
# 2          ...                                  NaN
# 3          ...                                  NaN
# 4          ...                                  NaN
# 5          ...                                  NaN
# 6          ...                                  NaN
# 7          ...                                  NaN
# 8          ...                                  NaN
# 9          ...                                  NaN
# 10         ...                                  NaN
# 11         ...                                  NaN
# 12         ...                                  NaN
# 13         ...                                  NaN
# 14         ...                                  NaN
# 15         ...                                  NaN
# 16         ...                                  NaN
# 17         ...                                  NaN
# 18         ...                                  NaN
# 19         ...                                  NaN
# 20         ...                                  NaN
# 21         ...                                  NaN
# 22         ...                                  NaN
# 23         ...                                  NaN
# 24         ...                                  NaN
# 25         ...                                  NaN
# 26         ...                                  NaN
# 27         ...                                  NaN
# 28         ...                                  NaN
# 29         ...                                  NaN
# ..         ...                                  ...
# 857        ...                                  NaN
# 858        ...                                  NaN
# 859        ...                                  NaN
# 860        ...                                  NaN
# 861        ...                                  NaN
# 862        ...                                  NaN
# 863        ...                                  NaN
# 864        ...                                  NaN
# 865        ...                                  NaN
# 866        ...                                  NaN
# 867        ...                                  NaN
# 868        ...                                  NaN
# 869        ...                                  NaN
# 870        ...                                  NaN
# 871        ...                                  NaN
# 872        ...                                  NaN
# 873        ...                                  NaN
# 874        ...                                  NaN
# 875        ...                                  NaN
# 876        ...                                  NaN
# 877        ...                                  NaN
# 878        ...                                  NaN
# 879        ...                                  NaN
# 880        ...                                  NaN
# 881        ...                                  NaN
# 882        ...                                  NaN
# 883        ...                                  NaN
# 884        ...                                  NaN
# 885        ...                                  NaN
# 886        ...                                  NaN
#
#     girl_dress_hollow_to_floor girl_dress_bust girl_dress_waist  \
# 0                          NaN             NaN              NaN
# 1                          NaN             NaN              NaN
# 2                          NaN             NaN              NaN
# 3                          NaN             NaN              NaN
# 4                          NaN             NaN              NaN
# 5                          NaN             NaN              NaN
# 6                          NaN             NaN              NaN
# 7                          NaN             NaN              NaN
# 8                          NaN             NaN              NaN
# 9                          NaN             NaN              NaN
# 10                         NaN             NaN              NaN
# 11                         NaN             NaN              NaN
# 12                         NaN             NaN              NaN
# 13                         NaN             NaN              NaN
# 14                         NaN             NaN              NaN
# 15                         NaN             NaN              NaN
# 16                         NaN             NaN              NaN
# 17                         NaN             NaN              NaN
# 18                         NaN             NaN              NaN
# 19                         NaN             NaN              NaN
# 20                         NaN             NaN              NaN
# 21                         NaN             NaN              NaN
# 22                         NaN             NaN              NaN
# 23                         NaN             NaN              NaN
# 24                         NaN             NaN              NaN
# 25                         NaN             NaN              NaN
# 26                         NaN             NaN              NaN
# 27                         NaN             NaN              NaN
# 28                         NaN             NaN              NaN
# 29                         NaN             NaN              NaN
# ..                         ...             ...              ...
# 857                        NaN             NaN              NaN
# 858                        NaN             NaN              NaN
# 859                        NaN             NaN              NaN
# 860                        NaN             NaN              NaN
# 861                        NaN             NaN              NaN
# 862                        NaN             NaN              NaN
# 863                        NaN             NaN              NaN
# 864                        NaN             NaN              NaN
# 865                        NaN             NaN              NaN
# 866                        NaN             NaN              NaN
# 867                        NaN             NaN              NaN
# 868                        NaN             NaN              NaN
# 869                        NaN             NaN              NaN
# 870                        NaN             NaN              NaN
# 871                        NaN             NaN              NaN
# 872                        NaN             NaN              NaN
# 873                        NaN             NaN              NaN
# 874                        NaN             NaN              NaN
# 875                        NaN             NaN              NaN
# 876                        NaN             NaN              NaN
# 877                        NaN             NaN              NaN
# 878                        NaN             NaN              NaN
# 879                        NaN             NaN              NaN
# 880                        NaN             NaN              NaN
# 881                        NaN             NaN              NaN
# 882                        NaN             NaN              NaN
# 883                        NaN             NaN              NaN
# 884                        NaN             NaN              NaN
# 885                        NaN             NaN              NaN
# 886                        NaN             NaN              NaN
#
#      girl_dress_hips girl_dress_sleeve girl_dress_inseam girl_dress_height  \
# 0                NaN               NaN               NaN               NaN
# 1                NaN               NaN               NaN               NaN
# 2                NaN               NaN               NaN               NaN
# 3                NaN               NaN               NaN               NaN
# 4                NaN               NaN               NaN               NaN
# 5                NaN               NaN               NaN               NaN
# 6                NaN               NaN               NaN               NaN
# 7                NaN               NaN               NaN               NaN
# 8                NaN               NaN               NaN               NaN
# 9                NaN               NaN               NaN               NaN
# 10               NaN               NaN               NaN               NaN
# 11               NaN               NaN               NaN               NaN
# 12               NaN               NaN               NaN               NaN
# 13               NaN               NaN               NaN               NaN
# 14               NaN               NaN               NaN               NaN
# 15               NaN               NaN               NaN               NaN
# 16               NaN               NaN               NaN               NaN
# 17               NaN               NaN               NaN               NaN
# 18               NaN               NaN               NaN               NaN
# 19               NaN               NaN               NaN               NaN
# 20               NaN               NaN               NaN               NaN
# 21               NaN               NaN               NaN               NaN
# 22               NaN               NaN               NaN               NaN
# 23               NaN               NaN               NaN               NaN
# 24               NaN               NaN               NaN               NaN
# 25               NaN               NaN               NaN               NaN
# 26               NaN               NaN               NaN               NaN
# 27               NaN               NaN               NaN               NaN
# 28               NaN               NaN               NaN               NaN
# 29               NaN               NaN               NaN               NaN
# ..               ...               ...               ...               ...
# 857              NaN               NaN               NaN               NaN
# 858              NaN               NaN               NaN               NaN
# 859              NaN               NaN               NaN               NaN
# 860              NaN               NaN               NaN               NaN
# 861              NaN               NaN               NaN               NaN
# 862              NaN               NaN               NaN               NaN
# 863              NaN               NaN               NaN               NaN
# 864              NaN               NaN               NaN               NaN
# 865              NaN               NaN               NaN               NaN
# 866              NaN               NaN               NaN               NaN
# 867              NaN               NaN               NaN               NaN
# 868              NaN               NaN               NaN               NaN
# 869              NaN               NaN               NaN               NaN
# 870              NaN               NaN               NaN               NaN
# 871              NaN               NaN               NaN               NaN
# 872              NaN               NaN               NaN               NaN
# 873              NaN               NaN               NaN               NaN
# 874              NaN               NaN               NaN               NaN
# 875              NaN               NaN               NaN               NaN
# 876              NaN               NaN               NaN               NaN
# 877              NaN               NaN               NaN               NaN
# 878              NaN               NaN               NaN               NaN
# 879              NaN               NaN               NaN               NaN
# 880              NaN               NaN               NaN               NaN
# 881              NaN               NaN               NaN               NaN
# 882              NaN               NaN               NaN               NaN
# 883              NaN               NaN               NaN               NaN
# 884              NaN               NaN               NaN               NaN
# 885              NaN               NaN               NaN               NaN
# 886              NaN               NaN               NaN               NaN
#
#     boy_actual_height girl_actual_height
# 0                 NaN                NaN
# 1                 NaN                NaN
# 2                 NaN                NaN
# 3                 NaN                NaN
# 4                 NaN                NaN
# 5                 NaN                NaN
# 6                 NaN                NaN
# 7                 NaN                NaN
# 8                 NaN                NaN
# 9                 NaN                NaN
# 10                NaN                NaN
# 11                NaN                NaN
# 12                NaN                NaN
# 13                NaN                NaN
# 14                NaN                NaN
# 15               30.5               30.5
# 16               32.0               32.0
# 17               35.0               35.0
# 18               35.0               35.0
# 19               38.0               38.0
# 20               41.0               41.0
# 21               43.5               43.5
# 22               46.0               46.0
# 23               48.5               48.5
# 24               51.0               51.0
# 25               53.0               53.0
# 26               55.0               55.0
# 27               58.0               58.0
# 28               61.0               61.0
# 29               92.0               92.0
# ..                ...                ...
# 857              55.0               55.0
# 858              57.0               57.0
# 859              59.0               59.0
# 860              61.0               61.0
# 861              28.0               28.0
# 862              30.0               30.0
# 863              32.0               32.0
# 864              67.0               67.0
# 865              71.0               71.0
# 866              74.0               74.0
# 867              81.0               81.0
# 868              86.0               86.0
# 869              94.0               94.0
# 870             102.0              102.0
# 871             108.0              108.0
# 872             114.0              114.0
# 873             126.0              126.0
# 874             138.0              138.0
# 875             150.0              150.0
# 876              80.0               80.0
# 877              86.0               86.0
# 878              92.0               92.0
# 879              98.0               98.0
# 880             104.0              104.0
# 881             110.0              110.0
# 882             116.0              116.0
# 883             122.0              122.0
# 884             128.0              128.0
# 885             140.0              140.0
# 886             152.0              152.0
#
# [887 rows x 54 columns]

# %%
all_weight = file['all_weight']
boy_weight = file['boy_weight']
girl_weight = file['girl_weight']
for i in range(len(all_height)):
    if type(boy_weight[i]) is not str and math.isnan(boy_weight[i]) is True:
        boy_weight[i] = all_weight[i]
    if type(girl_weight[i]) is not str and math.isnan(girl_weight[i]) is True:
        girl_weight[i] = all_weight[i]
file['boy_weight'] = boy_weight
file['girl_weight'] = girl_weight
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
file["boy_actual_weight"] = np.nan
file["girl_actual_weight"] = np.nan
file.head()
# Out:
#   index all_size boy_size girl_size all_height all_weight boy_height  \
# 0  #sen    6-9mo    6-9mo     6-9mo        NaN        NaN        NaN
# 1  #sen   9-12mo   9-12mo    9-12mo        NaN        NaN        NaN
# 2  #sen  12-18mo  12-18mo   12-18mo        NaN        NaN        NaN
# 3  #sen  18-24mo  18-24mo   18-24mo        NaN        NaN        NaN
# 4  #sen       2Y       2Y        2Y        NaN        NaN        NaN
#
#   boy_weight girl_height girl_weight        ...         girl_dress_bust  \
# 0        NaN         NaN         NaN        ...                     NaN
# 1        NaN         NaN         NaN        ...                     NaN
# 2        NaN         NaN         NaN        ...                     NaN
# 3        NaN         NaN         NaN        ...                     NaN
# 4        NaN         NaN         NaN        ...                     NaN
#
#   girl_dress_waist girl_dress_hips girl_dress_sleeve  girl_dress_inseam  \
# 0              NaN             NaN               NaN                NaN
# 1              NaN             NaN               NaN                NaN
# 2              NaN             NaN               NaN                NaN
# 3              NaN             NaN               NaN                NaN
# 4              NaN             NaN               NaN                NaN
#
#   girl_dress_height boy_actual_height girl_actual_height boy_actual_weight  \
# 0               NaN               NaN                NaN               NaN
# 1               NaN               NaN                NaN               NaN
# 2               NaN               NaN                NaN               NaN
# 3               NaN               NaN                NaN               NaN
# 4               NaN               NaN                NaN               NaN
#
#   girl_actual_weight
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
#
# [5 rows x 56 columns]

# %%
kg = ['kg', 'KG']
lbs = ['lbs', 'LBS']

# %%
def checkWeightUnit(data):
    unit = None
    for item in kg:
        if item in data:
            unit = 'kg'
            return unit
    for item in lbs:
        if item in data:
            unit = 'lbs'
            return unit

# %%
td = 'abdkg'
checkWeightUnit(td)
# Out:
# 'kg'

# %%
def weight_generalizer(weight, unit):
    for i in range(len(weight)):
        if checkWeightUnit(weight[i]) is not None:
            unit = checkWeightUnit(weight[i])
        nums = re.findall(r'\d+\.?\d+', data)
        if len(nums) is 1:
            weight[i] = nums[0] + unit
        else:
            weight[i] = nums[0] + '-' + nums[1] + unit

# %%
weight_columns = ['all_weight', 'boy_weight', 'girl_weight']
for column in weight_columns:
    weight = file[column]
    weight_generalizer(weight, unit)
    file[column] = weight
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-80-7cb1e32e1384> in <module>()
#       2 for column in weight_columns:
#       3     weight = file[column]
# ----> 4     weight_generalizer(weight, unit)
#       5     file[column] = weight
#
# <ipython-input-79-36399814dc54> in weight_generalizer(weight, unit)
#       1 def weight_generalizer(weight, unit):
#       2     for i in range(len(weight)):
# ----> 3         if checkWeightUnit(weight[i]) is not None:
#       4             unit = checkWeightUnit(weight[i])
#       5         nums = re.findall(r'\d+\.?\d+', data)
#
# <ipython-input-78-70f261dcd253> in checkWeightUnit(data)
#       2     unit = None
#       3     for item in kg:
# ----> 4         if item in data:
#       5             unit = 'kg'
#       6             return unit
#
# TypeError: argument of type 'float' is not iterable
